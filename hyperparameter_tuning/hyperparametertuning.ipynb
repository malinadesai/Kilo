# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# # Embedding Top 10 Hyperparameter Searches

# %%
run2 = pd.read_csv('train_se_c9fb2_00002_2_batch_size=50,kernel_size=5,lr=0.0000,num_blocks=4,num_dim=7,num_dim_final=5,num_hidden_layers_f=1,num_hidd_2024-05-13_17-14-31.csv')
run3 = pd.read_csv('train_se_c9fb2_00003_3_batch_size=25,kernel_size=7,lr=0.0000,num_blocks=4,num_dim=7,num_dim_final=5,num_hidden_layers_f=1,num_hidd_2024-05-13_17-14-31.csv')
run7 = pd.read_csv('train_se_c9fb2_00007_7_batch_size=25,kernel_size=7,lr=0.0000,num_blocks=6,num_dim=5,num_dim_final=2,num_hidden_layers_f=1,num_hidd_2024-05-13_17-14-31.csv')
run10 = pd.read_csv('train_se_c9fb2_00010_10_batch_size=25,kernel_size=7,lr=0.0000,num_blocks=6,num_dim=8,num_dim_final=2,num_hidden_layers_f=1,num_hid_2024-05-13_17-14-31.csv')
run11 = pd.read_csv('train_se_c9fb2_00011_11_batch_size=25,kernel_size=5,lr=0.0000,num_blocks=3,num_dim=5,num_dim_final=2,num_hidden_layers_f=1,num_hid_2024-05-13_17-14-31.csv')
run17 = pd.read_csv('train_se_c9fb2_00017_17_batch_size=25,kernel_size=9,lr=0.0000,num_blocks=5,num_dim=5,num_dim_final=2,num_hidden_layers_f=1,num_hid_2024-05-13_17-28-16.csv')
run31 = pd.read_csv('train_se_c9fb2_00031_31_batch_size=25,kernel_size=7,lr=0.0000,num_blocks=6,num_dim=5,num_dim_final=2,num_hidden_layers_f=1,num_hid_2024-05-13_18-05-40.csv')
run40 = pd.read_csv('train_se_c9fb2_00040_40_batch_size=50,kernel_size=9,lr=0.0000,num_blocks=3,num_dim=8,num_dim_final=2,num_hidden_layers_f=1,num_hid_2024-05-13_18-13-28.csv')
run48 = pd.read_csv('train_se_c9fb2_00048_48_batch_size=50,kernel_size=9,lr=0.0001,num_blocks=5,num_dim=8,num_dim_final=2,num_hidden_layers_f=1,num_hid_2024-05-13_18-29-50.csv')
run98 = pd.read_csv('train_se_c9fb2_00098_98_batch_size=50,kernel_size=7,lr=0.0000,num_blocks=4,num_dim=4,num_dim_final=5,num_hidden_layers_f=1,num_hid_2024-05-13_19-11-34.csv')

# %%
num_plots = 10

colormap = plt.cm.gist_ncar
plt.gca().set_prop_cycle(plt.cycler('color', plt.cm.winter(np.linspace(0, 1, num_plots))))

plt.plot(run17['Step'], run17['Value'], label = 'trial 17')
plt.plot(run11['Step'], run11['Value'], label = 'trial 11')
plt.plot(run3['Step'], run3['Value'], label = 'trial 3')
plt.plot(run98['Step'], run98['Value'], label = 'trial 98')
plt.plot(run40['Step'], run40['Value'], label = 'trial 40')
plt.plot(run10['Step'], run10['Value'], label = 'trial 10')
plt.plot(run31['Step'], run31['Value'], label = 'trial 31')
plt.plot(run7['Step'], run7['Value'], label = 'trial 7')
plt.plot(run48['Step'], run48['Value'], label = 'trial 48')
plt.plot(run2['Step'], run2['Value'], label = 'trial 2')


plt.xlim(0, 50)
plt.legend()
plt.xlabel('Steps')
plt.ylabel('Avg. Training Loss')

plt.savefig("HyperparameterEmbeddingLossCurves.pdf", format="pdf", bbox_inches="tight")

# %% [markdown]
# # Flow Top 10 Hyperparameter Searches

# %%
run0_flow = pd.read_csv('train_flow_af40f_00000_0_batch_size=100,hidden_features=100,lr=0.0001,num_blocks=8,num_transforms=5_2024-05-15_15-09-42.csv')
run4_flow = pd.read_csv('train_flow_af40f_00004_4_batch_size=25,hidden_features=100,lr=0.0000,num_blocks=10,num_transforms=4_2024-05-15_15-09-42.csv')
run11_flow = pd.read_csv('train_flow_af40f_00011_11_batch_size=25,hidden_features=80,lr=0.0000,num_blocks=9,num_transforms=7_2024-05-15_15-09-42.csv')
run19_flow = pd.read_csv('train_flow_af40f_00019_19_batch_size=25,hidden_features=70,lr=0.0000,num_blocks=6,num_transforms=5_2024-05-15_15-25-48.csv')
run28_flow = pd.read_csv('train_flow_af40f_00028_28_batch_size=25,hidden_features=100,lr=0.0001,num_blocks=10,num_transforms=6_2024-05-15_16-22-34.csv')
run40_flow = pd.read_csv('train_flow_af40f_00040_40_batch_size=25,hidden_features=90,lr=0.0001,num_blocks=9,num_transforms=5_2024-05-15_16-37-29.csv')
run57_flow = pd.read_csv('train_flow_af40f_00057_57_batch_size=25,hidden_features=90,lr=0.0001,num_blocks=6,num_transforms=5_2024-05-15_18-07-07.csv')
run65_flow = pd.read_csv('train_flow_af40f_00065_65_batch_size=25,hidden_features=70,lr=0.0000,num_blocks=9,num_transforms=6_2024-05-15_18-10-05.csv')
run75_flow = pd.read_csv('train_flow_af40f_00075_75_batch_size=25,hidden_features=70,lr=0.0001,num_blocks=10,num_transforms=7_2024-05-15_18-32-47.csv')
run98_flow = pd.read_csv('train_flow_af40f_00098_98_batch_size=25,hidden_features=80,lr=0.0001,num_blocks=9,num_transforms=6_2024-05-15_19-23-59.csv')

# %%
num_plots = 10

colormap = plt.cm.gist_ncar
plt.gca().set_prop_cycle(plt.cycler('color', plt.cm.winter(np.linspace(0, 1, num_plots))))

plt.plot(run65_flow['Step'], run65_flow['Value'], label = 'trial 65')
plt.plot(run19_flow['Step'], run19_flow['Value'], label = 'trial 19')
plt.plot(run11_flow['Step'], run11_flow['Value'], label = 'trial 11')
plt.plot(run0_flow['Step'], run0_flow['Value'], label = 'trial 0')
plt.plot(run4_flow['Step'], run4_flow['Value'], label = 'trial 4')
plt.plot(run75_flow['Step'], run75_flow['Value'], label = 'trial 75')
plt.plot(run57_flow['Step'], run57_flow['Value'], label = 'trial 57')
plt.plot(run28_flow['Step'], run28_flow['Value'], label = 'trial 28')
plt.plot(run98_flow['Step'], run98_flow['Value'], label = 'trial 98')
plt.plot(run40_flow['Step'], run40_flow['Value'], label = 'trial 40')

plt.legend()
plt.xlabel('Steps')
plt.ylabel('Avg. Training Loss')

plt.savefig("HyperparameterFlowLossCurves.pdf", format="pdf", bbox_inches="tight")
